# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('./helpers/')

# %%
from frame_extraction_function import *

# %%
df_new = pd.read_csv('./frame_extraction_csv_files/survey2012_folder_KP155.800-186.495_D.csv')

# %%
codes = ['AN']
df_new = df_new[df_new['Observation Code'].isin(codes)]
df_new = df_new.reset_index(drop=True); df_new
# Out:
#                     folder                           video1  offset_Ch1  \
# 0   DATA_20120927015213796  20120927015213796@DVR-1_Ch1.mpg    1450.298
# 1   DATA_20120927171205859  20120927171205859@DVR-1_Ch1.mpg      30.759
# 2   DATA_20120927171205859  20120927171205859@DVR-1_Ch1.mpg     335.501
# 3   DATA_20120927171205859  20120927171205859@DVR-1_Ch1.mpg     690.955
# 4   DATA_20120927171205859  20120927171205859@DVR-1_Ch1.mpg     971.155
# ..                     ...                              ...         ...
# 83  DATA_20120927110429188  20120927110429516@DVR-1_Ch1.mpg    1615.657
# 84  DATA_20120927022214938  20120927022214938@DVR-1_Ch1.mpg     856.062
# 85  DATA_20120927022214938  20120927022214938@DVR-1_Ch1.mpg    1278.605
# 86  DATA_20120927022214938  20120927022214938@DVR-1_Ch1.mpg    1773.546
# 87  DATA_20120927012212250  20120927012212625@DVR-1_Ch1.mpg     196.265
#
#                              video2  offset_Ch2  \
# 0   20120927015214843@DVR-1_Ch2.mpg    1449.251
# 1   20120927171206656@DVR-1_Ch2.mpg      29.962
# 2   20120927171206656@DVR-1_Ch2.mpg     334.704
# 3   20120927171206656@DVR-1_Ch2.mpg     690.158
# 4   20120927171206656@DVR-1_Ch2.mpg     970.358
# ..                              ...         ...
# 83  20120927110429578@DVR-1_Ch2.mpg    1615.595
# 84  20120927022216000@DVR-1_Ch2.mpg     855.000
# 85  20120927022216000@DVR-1_Ch2.mpg    1277.543
# 86  20120927022216000@DVR-1_Ch2.mpg    1772.484
# 87  20120927012212687@DVR-1_Ch2.mpg     196.203
#
#                              video3  offset_Ch3        VWTimestamp VWIsAuto  \
# 0   20120927015215906@DVR-1_Ch3.mpg    1448.188  20120927021624094        F
# 1   20120927171207265@DVR-1_Ch3.mpg      29.353  20120927171236618        F
# 2   20120927171207265@DVR-1_Ch3.mpg     334.095  20120927171741360        F
# 3   20120927171207265@DVR-1_Ch3.mpg     689.549  20120927172336814        F
# 4   20120927171207265@DVR-1_Ch3.mpg     969.749  20120927172817014        F
# ..                              ...         ...                ...      ...
# 83  20120927110429188@DVR-1_Ch3.mpg    1615.985  20120927113125173        F
# 84  20120927022217078@DVR-1_Ch3.mpg     853.922  20120927023631000        F
# 85  20120927022217078@DVR-1_Ch3.mpg    1276.465  20120927024333543        F
# 86  20120927022217078@DVR-1_Ch3.mpg    1771.406  20120927025148484        F
# 87  20120927012212250@DVR-1_Ch3.mpg     196.640  20120927012528890        F
#
#           Date  ... Location [DP] Location [DB] Crossing Type Orientation  \
# 0   27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 1   27/09/2012  ...        Unseen        Unseen  Not Recorded        0.00
# 2   27/09/2012  ...        Unseen        OnPipe  Not Recorded        0.00
# 3   27/09/2012  ...        Unseen        Unseen  Not Recorded        0.00
# 4   27/09/2012  ...        Unseen        OnPipe  Not Recorded        0.00
# ..         ...  ...           ...           ...           ...         ...
# 83  27/09/2012  ...        Unseen        OnPipe  Not Recorded        0.00
# 84  27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 85  27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 86  27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 87  27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
#
#    Event Code [DB] Event Code [FT]  Size Size [DB]  Type [MO]  \
# 0              DB0             FT0   0.0      None  No Record
# 1              DB0             FT0  0.00      None  No Record
# 2              DB0             FT0  0.00      None  No Record
# 3              DB0             FT0  0.00      None  No Record
# 4              DB0             FT0  0.00      None  No Record
# ..             ...             ...   ...       ...        ...
# 83             DB0             FT0  0.00      None  No Record
# 84             DB0             FT0   0.0      None  No Record
# 85             DB0             FT0   0.0      None  No Record
# 86             DB0             FT0   0.0      None  No Record
# 87             DB0             FT0   0.0      None  No Record
#
#    Sediment Coverage
# 0       Not Recorded
# 1       Not Recorded
# 2            Partial
# 3       Not Recorded
# 4       Not Recorded
# ..               ...
# 83      Not Recorded
# 84      Not Recorded
# 85      Not Recorded
# 86      Not Recorded
# 87      Not Recorded
#
# [88 rows x 47 columns]

# %%
len(df_new)
# Out:
# 88

# %%
p = Path('/media/scratch/astamoulakatos/SURVEY2012/KP155.800-186.495_D/')

# %%
path_to_save = Path('/media/raid/astamoulakatos/DOMAIN_ADAPTATION/Survey2012/')

# %%
#save = path_to_save/'centre/anode/'; save

# %%
df_anode = df_new

# %%
#frames = 0
for k in tqdm(range(0,len(df_anode))): 
    video1 = p/df_anode.folder[k]/df_anode.video1[k]
    video2 = p/df_anode.folder[k]/df_anode.video2[k]
    video3 = p/df_anode.folder[k]/df_anode.video3[k]
    
    start = float(df_anode['offset_Ch2'][k] - 1)*1000
    stop = float(df_anode['offset_Ch2'][k] + 0.5)*1000
    save = path_to_save/'centre/anode/'
    extract_frames(k, str(video2), str(save), 'anode', 2, start, stop, nframes=6)   
    
    start = float(df_anode['offset_Ch1'][k] - 1)*1000
    stop = float(df_anode['offset_Ch1'][k] + 0.5)*1000
    save = path_to_save/'left/anode/'
    extract_frames(k, str(video1), str(save), 'anode', 1, start, stop, nframes=6)
    
    start = float(df_anode['offset_Ch3'][k] - 1)*1000
    stop = float(df_anode['offset_Ch3'][k] + 0.5)*1000
    save = path_to_save/'right/anode/'
    extract_frames(k, str(video3), str(save), 'anode', 3, start, stop, nframes=6)
# Out:
#  24%|██▍       | 21/88 [00:04<00:12,  5.18it/s]

# %%
# # SEEK TO LOCATION OF EVENT FOR EACH VIDEO USING MILISECONDS
# import os
# import matplotlib.pyplot as plt
# %matplotlib inline
# import cv2


# for i in range(len(df_new)):
#     vid1 = p/df_new.folder[i]/df_new.video1[i]
#     vid2 = p/df_new.folder[i]/df_new.video2[i]
#     vid3 = p/df_new.folder[i]/df_new.video3[i]
    
#     location1 = float(df_new['offset_Ch1'][i])*1000
#     #print(location)
#     cap = cv2.VideoCapture(str(vid1))
#     cap.set(cv2.CAP_PROP_POS_MSEC, location1)
#     #cap.set(cv2.CAP_PROP_POS_FRAMES, location)
#     success1,image1 = cap.read()
    
#     location2 = float(df_new['offset_Ch2'][i])*1000
#     #print(location)
#     cap = cv2.VideoCapture(str(vid2))
#     cap.set(cv2.CAP_PROP_POS_MSEC, location2)
#     #cap.set(cv2.CAP_PROP_POS_FRAMES, location)
#     success2,image2 = cap.read()
    
    
#     location3 = float(df_new['offset_Ch3'][i])*1000
#     #print(location)
#     cap = cv2.VideoCapture(str(vid3))
#     cap.set(cv2.CAP_PROP_POS_MSEC, location3)
#     #cap.set(cv2.CAP_PROP_POS_FRAMES, location)
#     success3 ,image3 = cap.read()
    
#     if (success1 & success2 & success3):
#         plt.figure(figsize=(19,5))
#         plt.suptitle('Event: {}  ,  Folder: {}'.format(df_new['Description'][i], df_new['folder'][i]), fontsize=18)
#         #plt.tight_layout()
#         plt.subplot(131)
#         plt.title('offset1 = {:.3f} sec'.format(location1/1000))
#         plt.axis('off')
#         plt.imshow(image1)
        
#         plt.subplot(132)
#         plt.title('offset2 = {:.3f} sec'.format(location2/1000))
#         plt.axis('off')
#         plt.imshow(image2)

#         plt.subplot(133)
#         plt.title('offset3 = {:.3f} sec'.format(location3/1000))
#         plt.axis('off')
#         plt.imshow(image3)
#         #plt.savefig('./subplots/subplot{}.jpg'.format(i))
