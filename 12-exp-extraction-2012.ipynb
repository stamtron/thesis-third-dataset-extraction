10/2012  ...        Unseen        Unseen   Not Recorded         0.0
# 3729  06/10/2012  ...        Unseen        Unseen   Not Recorded         0.0
#
#      Event Code [DB] Event Code [FT] Size Size [DB]  Type [MO]  \
# 0                DB0             FT0  0.0      None  No Record
# 1                DB0             FT0  0.0      None  No Record
# 2                DB0             FT0  0.0      None  No Record
# 3                DB0             FT0  0.0      None  No Record
# 4                DB0             FT0  0.0      None  No Record
# ...              ...             ...  ...       ...        ...
# 3725             DB0             FT0  0.0      None  No Record
# 3726             DB0             FT0  0.0      None  No Record
# 3727             DB0             FT0  0.0      None  No Record
# 3728             DB0             FT0  0.0      None  No Record
# 3729             DB0             FT0  0.0      None  No Record
#
#      Sediment Coverage
# 0         Not Recorded
# 1         Not Recorded
# 2         Not Recorded
# 3         Not Recorded
# 4         Not Recorded
# ...                ...
# 3725      Not Recorded
# 3726      Not Recorded
# 3727      Not Recorded
# 3728      Not Recorded
# 3729      Not Recorded
#
# [3730 rows x 47 columns]

# %%
len(df_new)
# Out:
# 3730

# %%
p = Path('/media/scratch/astamoulakatos/SURVEY2012/KP078.553-119.732_A/')

# %%
path_to_save = Path('/media/scratch/astamoulakatos/DOMAIN_ADAPTATION/Survey2012/')

# %%
frames = 0
for k in tqdm(range(0,len(df_new)-1)): 
    video1 = p/df_new.folder[k]/df_new.video1[k]
    video2 = p/df_new.folder[k]/df_new.video2[k]
    video3 = p/df_new.folder[k]/df_new.video3[k]
    if df_new.folder[k] == df_new.folder[k+1]:
    #if (df_new['KP'][k] < df_new['KP'][k+1]):
        searchfor = ['FJ', 'AN']   
        if (any(x in df_new['Observation Code'][k] for x in searchfor) and (any(x in df_new['Observation Code'][k+1] for x in searchfor))):
            start = float(df_new['offset_Ch2'][k] + 4) * 1000
            stop = float(df_new['offset_Ch2'][k+1] - 4) * 1000
            nframes = int((stop-start)/34000)
            #print(nframes)
            frames = frames + nframes
            save = path_to_save/'centre/exp/'
            extract_frames(k, str(video2), str(save), 'exp',  2, start, stop, nframes=nframes)  
            
            start = float(df_new['offset_Ch1'][k] + 4) * 1000
            stop = float(df_new['offset_Ch1'][k+1] - 4) * 1000
            save = path_to_save/'left/exp/'
            extract_frames(k, str(video1), str(save), 'exp',  1, start, stop, nframes=nframes)
            
            start = float(df_new['offset_Ch3'][k] + 4) * 1000
            stop = float(df_new['offset_Ch3'][k+1] - 4) * 1000
            save = path_to_save/'right/exp/'
            extract_frames(k, str(video3), str(save), 'exp',  3, start, stop, nframes=nframes)
# Out:
#  56%|█████▌    | 2087/3729 [02:50<02:13, 12.27it/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-29-19425b097394> in <module>
#      24             stop = float(df_new['offset_Ch3'][k+1] - 4) * 1000
#      25             save = path_to_save/'right/exp/'
# ---> 26             extract_frames(k, str(video3), str(save), 'exp',  3, start, stop, nframes=nframes)
#
# ~/Jupyter/nsea-dataset-extraction/helpers/frame_extraction_function.py in extract_frames(k, video_path, path_to_save, event, channel, start, stop, nframes)
#      54         cap.set(cv2.CAP_PROP_POS_FRAMES, int(frames[j]))
#      55         suc,im = cap.read()
# ---> 56         cv2.imwrite(path_to_save + '_channel' + str(channel) + '_frame' + '{:06d}'.format(j) + '.png', im)
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-7m_g9lbm/opencv/modules/imgcodecs/src/loadsave.cpp:753: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
frames
# Out:
# 955
