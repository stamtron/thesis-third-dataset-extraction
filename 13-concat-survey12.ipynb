# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import datetime as dt
import csv
from pathlib import Path
import datetime as dt

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (20,15)
font = {'family' : 'DejaVu Sans',  'weight' : 'normal',  'size'  : 26}
plt.rc('font', **font)

# %%
df1 = pd.read_csv('frame_extraction_csv_files/survey2012_folder_KP078.553-119.732_A.csv')
df2 = pd.read_csv('frame_extraction_csv_files/survey2012_folder_KP155.800-186.495_D.csv')
df3 = pd.read_csv('frame_extraction_csv_files/survey2012_folder_KP145.020-155.882_A.csv')

# %%
df_all = pd.concat([df1,df2,df3],ignore_index=True)

# %%
events = df_all.Description.value_counts()

# %%
events
# Out:
# Field Joint                3799
# Anode                       544
# Field Joint.End             321
# Field Joint.Start           321
# Exposure Start              304
# Exposure End                304
# Suspension Start            208
# Suspension End              208
# Debris                      139
# Anode.Start                  77
# Anode.End                    77
# CP Stab                      46
# Rock Dump Start              34
# Rock Dump End                34
# Field Joint Damage           24
# Pipeline Crossing             4
# Concrete Coating Damage       4
# Other Features                3
# Sea Marker                    3
# Grout Bag                     2
# Rock Dump                     1
# Name: Description, dtype: int64

# %%
events.drop(['Field Joint' , 'Anode']).plot(kind='barh')
plt.title('Survey 2012 Annotated Events')
plt.savefig('events_2012.png', dpi=500, bbox_inches = 'tight')
plt.show()

# %%
df1.Description.unique()
# Out:
# array(['Exposure - End', 'Field Joint - Normal', 'Exposure - Start',
#        'Field Joint', 'Anode - Bracelet - slight wastage 0-25%',
#        'Debris - Netting', 'Exposure - intermittent start',
#        'Exposure - intermittent  end',
#        'Anode - Bracelet - moderate wastage 25-50%', 'Debris - Soft rope',
#        'Debris - Boulder', 'Stabilisation - Rockdump - Start',
#        'Other Fixed - End of weightcoat', 'Other Fixed - Pipe bend',
#        'Other Fixed - Clamp', 'Other Fixed - Flange',
#        'Measurement - CP Stab', 'Survey Section - End of - Pipe exposed',
#        'Debris - Other soft debris', 'Weightcoat Missing - End of loss',
#        'Weightcoat Missing - Start of loss',
#        'Stabilisation - Mattress - End',
#        'Stabilisation - Mattress - Start', 'Debris - Metalwork',
#        'Span - End', 'Span - Start', 'Debris - Other hard debris',
#        'Stabilisation - Rockdump - End',
#        'Survey Section - End of - Pipe buried',
# ...
