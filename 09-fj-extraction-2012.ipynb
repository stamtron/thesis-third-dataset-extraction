09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 1    26/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 2    26/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 3    26/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 4    27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# ..          ...  ...           ...           ...           ...         ...
# 801  27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 802  27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 803  27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 804  27/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
# 805  26/09/2012  ...        Unseen        Unseen  Not Recorded         0.0
#
#     Event Code [DB] Event Code [FT] Size Size [DB]  Type [MO]  \
# 0               DB0             FT0  0.0      None  No Record
# 1               DB0             FT0  0.0      None  No Record
# 2               DB0             FT0  0.0      None  No Record
# 3               DB0             FT0  0.0      None  No Record
# 4               DB0             FT0  0.0      None  No Record
# ..              ...             ...  ...       ...        ...
# 801             DB0             FT0  0.0      None  No Record
# 802             DB0             FT0  0.0      None  No Record
# 803             DB0             FT0  0.0      None  No Record
# 804             DB0             FT0  0.0      None  No Record
# 805             DB0             FT0  0.0      None  No Record
#
#     Sediment Coverage
# 0        Not Recorded
# 1        Not Recorded
# 2        Not Recorded
# 3        Not Recorded
# 4        Not Recorded
# ..                ...
# 801      Not Recorded
# 802      Not Recorded
# 803      Not Recorded
# 804      Not Recorded
# 805      Not Recorded
#
# [806 rows x 47 columns]

# %%
len(df_new)
# Out:
# 200

# %%
df_new = df_new.sample(n = 200)

# %%
p = Path('/media/scratch/astamoulakatos/SURVEY2012/KP155.800-186.495_D/')

# %%
path_to_save = Path('/media/scratch/astamoulakatos/DOMAIN_ADAPTATION/Survey2012/')

# %%
#save = path_to_save/'centre/anode/'; save

# %%
#df_anode = df_new

# %%
df_new = df_new.reset_index(drop=True)

# %% [markdown]
# # if these fj events are not easily identified try with the start and stop timestamps

# %%
#frames = 0
for k in tqdm(range(0,len(df_new))): 
    video1 = p/df_new.folder[k]/df_new.video1[k]
    video2 = p/df_new.folder[k]/df_new.video2[k]
    video3 = p/df_new.folder[k]/df_new.video3[k]
    
    start = float(df_new['offset_Ch2'][k] - 1)*1000
    stop = float(df_new['offset_Ch2'][k] + 0.5)*1000
    save = path_to_save/'centre/fj/'
    extract_frames(k, str(video2), str(save), 'fj', 2, start, stop, nframes=3)   
    
    start = float(df_new['offset_Ch1'][k] - 1)*1000
    stop = float(df_new['offset_Ch1'][k] + 0.5)*1000
    save = path_to_save/'left/fj/'
    extract_frames(k, str(video1), str(save), 'fj', 1, start, stop, nframes=3)
    
    start = float(df_new['offset_Ch3'][k] - 1)*1000
    stop = float(df_new['offset_Ch3'][k] + 0.5)*1000
    save = path_to_save/'right/fj/'
    extract_frames(k, str(video3), str(save), 'fj', 3, start, stop, nframes=3)
# Out:
# 100%|██████████| 200/200 [00:51<00:00,  3.92it/s]
